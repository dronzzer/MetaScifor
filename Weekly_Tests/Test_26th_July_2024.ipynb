# %% [markdown]
# Create a student management system project using the classes and objects concept in python which should perform the following operations
#
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit

# %%
class Student:
  def __init__(self,id,name,age,grade):
    self.id=id
    self.name=name
    self.age=age
    self.grade=grade
  def display(self):
    print(f"id :{self.id} name: {self.name} age: {self.age} grade: {self.grade} ")


class management:
  def __init__(self):
    self.students=[]

  def add(self):
    id=input("Enter the id of the student: ")
    name=input("Enter the name of student: ")
    age=input("Enter the age of the student: ")
    grade=input("Enter the Grade in which student is present: ")
    student=Student(id,name,age,grade)
    self.students.append(student)
    print("Student added successfully")


  def show(self):
    if not self.students:
      print("No Student Record found")
    else:
      for student in self.students:
        student.display()

  def search(self):
    sid=input("Enter the id of the student to search: ")
    for student in self.students:
      if student.id==sid:
        student.display()
        return
    print("Student not Found")

  def delete(self):
    del_id=input("Enter the id of the student to delete ")
    for student in self.students:
      if student.id==del_id:
        self.students.remove(student)
        return
    print("Student not Found")

  def update(self):
    sid=input("Enter the id of the student to search: ")
    for student in self.students:
      if student.id==sid:
        student.name = input("Enter new name: ")
        student.age = int(input("Enter new age: "))
        student.grade = input("Enter new grade: ")
        print("Student details updated successfully!\n")
        return
    print("Student not found.\n")








def main():
  obj=management()
  while True:
    opt=input("""Welcome to the student Management System!!
  Select an option:
1.Accept Student details

2.Display Student Details

3.Search Details of a Student

4.Delete Details of Student

5.Update Student Details

6.Exit  """)


    if opt=='1':
      obj.add()
    elif opt=='2':
      obj.show()
    elif opt=='3':
      obj.search()
    elif opt=='4':
      obj.delete()
    elif opt=='5':
      obj.update()
    else:
      print("Invalid option")
      break

if __name__=="__main__":
  main()
# Out:
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  1
# Enter the id of the student: 1
# Enter the name of student: Khushwant
# Enter the age of the student: 22
# Enter the Grade in which student is present: 11
# Student added successfully
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  2
# id :1 name: Khushwant age: 22 grade: 11
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  3
# Enter the id of the student to search: 1
# id :1 name: Khushwant age: 22 grade: 11
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  5
# Enter the id of the student to search: 1
# Enter new name: amit
# Enter new age: 21
# Enter new grade: 11
# Student details updated successfully!
#
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  2
# id :1 name: amit age: 21 grade: 11
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  4
# Enter the id of the student to delete 1
# Student not Found
# Welcome to the student Management System!!
#   Select an option:
# 1.Accept Student details
#
# 2.Display Student Details
#
# 3.Search Details of a Student
#
# 4.Delete Details of Student
#
# 5.Update Student Details
#
# 6.Exit  6
# Invalid option

# %% [markdown]
# Nidhi is trying to understand how the phone gets updated with
# new features with all the old features already available in the new phone.
# Write a program to explain this with the help of inheritance and method
# overriding. Hint: Create class Nokia1, then create class Nokia2 and
# inherit all the methods from Nokia1 to Nokia2. Also, modify the required
# methods in Nokia2 and add a few additional methods as well. In the
# same way, you can create Nokia3 and Nokia4 as well

# %%
class Nokia1:
  def __init__(self,x,y):
    self.x=x
    self.y=y
  def add(self):
    return self.x+self.y

class Nokia2(Nokia1):

  def diff(self):
    return self.x-self.y

class Nokia3(Nokia2):

  def prod(self):
    return self.x*self.y

class Nokia4(Nokia3):

  def div(self):
    return self.x/self.y

a=10
b=5
obj=Nokia4(a,b)
print(obj.add())
print(obj.diff())
print(obj.prod())
print(obj.div())
# Out:
# 15
# 5
# 50
# 2.0
